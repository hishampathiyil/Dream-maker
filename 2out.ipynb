# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\look at me\Downloads\dataset _soccer_attribute.csv')

# %%
data.head()
# Out:
#        UID            Name  NationID        Born   Age  IntCaps  IntGoals  \
# 0  1000055  Wilfred Bamnjo        11  27-03-1980  36.0        0         0
# 1  1000331        Wang Wei       110  20-02-1982  34.0        0         0
# 2  1000334        Liu Yang       110  11-04-1982  34.0        0         0
# 3  1000337         Song Qi       110  07-04-1985  31.0        0         0
# 4  1000340        Chen Lei       110  20-01-1983  33.0        0         0
#
#    U21Caps  U21Goals  Height  ...  AttackingMidRight  DefenderCentral  \
# 0        0         0   178.0  ...                  1                1
# 1        0         0   188.0  ...                  1                1
# 2        0         0   183.0  ...                  1                1
# 3        0         0   170.0  ...                  1                1
# 4        0         0   181.0  ...                  1                1
#
#    DefenderLeft  DefenderRight  DefensiveMidfielder  MidfielderCentral  \
# ...

# %%
data.columns
# Out:
# Index(['UID', 'Name', 'NationID', 'Born', 'Age', 'IntCaps', 'IntGoals',
#        'U21Caps', 'U21Goals', 'Height', 'Weight', 'AerialAbility',
#        'CommandOfArea', 'Communication', 'Eccentricity', 'Handling', 'Kicking',
#        'OneOnOnes', 'Reflexes', 'RushingOut', 'TendencyToPunch', 'Throwing',
#        'Corners', 'Crossing', 'Dribbling', 'Finishing', 'FirstTouch',
#        'Freekicks', 'Heading', 'LongShots', 'Longthrows', 'Marking', 'Passing',
#        'PenaltyTaking', 'Tackling', 'Technique', 'Aggression', 'Anticipation',
#        'Bravery', 'Composure', 'Concentration', 'Vision', 'Decisions',
#        'Determination', 'Flair', 'Leadership', 'OffTheBall', 'Positioning',
#        'Teamwork', 'Workrate', 'Acceleration', 'Agility', 'Balance', 'Jumping',
#        'LeftFoot', 'NaturalFitness', 'Pace', 'RightFoot', 'Stamina',
#        'Strength', 'Consistency', 'Dirtiness', 'ImportantMatches',
#        'InjuryProness', 'Versatility', 'Adaptability', 'Ambition', 'Loyalty',
# ...

# %%
data.isna().sum()[data.isna().sum()>0]
# Out:
# Age              300
# Height           293
# PositionsDesc     32
# dtype: int64

# %%
freqgraph=data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(10,8))
plt.show()

# %%
data['Age']=data['Age'].fillna(data['Age'].median())

# %%
data['Height']=data['Height'].fillna(data['Height'].mean())

# %%
data['PositionsDesc'] = data['PositionsDesc'].fillna(method = 'ffill')

# %%
pd.set_option("display.max.columns", None)

data.describe()
# Out:
#                 UID      NationID            Age        IntCaps  \
# count  1.595410e+05  1.595410e+05  159541.000000  159541.000000
# mean   1.368157e+08  7.621294e+04      23.567509       0.988987
# std    3.492948e+08  2.051496e+06       5.628429       6.642102
# min    5.100000e+02  5.000000e+00      14.000000       0.000000
# 25%    1.902265e+07  7.610000e+02      19.000000       0.000000
# 50%    4.104476e+07  7.760000e+02      23.000000       0.000000
# 75%    6.723302e+07  7.990000e+02      27.000000       0.000000
# max    1.394674e+09  6.200213e+07      54.000000     166.000000
#
#             IntGoals        U21Caps       U21Goals         Height  \
# count  159541.000000  159541.000000  159541.000000  159541.000000
# mean        0.108148       0.507424       0.065883     180.026826
# std         1.269210       2.535295       0.591362       7.210828
# min         0.000000       0.000000       0.000000     149.000000
# ...

# %%
data.drop(['UID'],axis=1,inplace=True)

# %%
data.drop(['Born'],axis=1,inplace=True)

# %%
data.drop(['NationID'],axis=1,inplace=True)

# %%
data.describe()
# Out:
#                  Age        IntCaps       IntGoals        U21Caps  \
# count  159541.000000  159541.000000  159541.000000  159541.000000
# mean       23.567509       0.988987       0.108148       0.507424
# std         5.628429       6.642102       1.269210       2.535295
# min        14.000000       0.000000       0.000000       0.000000
# 25%        19.000000       0.000000       0.000000       0.000000
# 50%        23.000000       0.000000       0.000000       0.000000
# 75%        27.000000       0.000000       0.000000       0.000000
# max        54.000000     166.000000      65.000000      62.000000
#
#             U21Goals         Height         Weight  AerialAbility  \
# count  159541.000000  159541.000000  159541.000000  159541.000000
# mean        0.065883     180.026826      45.874922       2.991613
# std         0.591362       7.210828      36.340693       2.901983
# min         0.000000     149.000000       0.000000       1.000000
# ...

# %%
data.plot(kind="box",subplots=True,layout=(12,8),figsize=(15,20));

# %% [raw]
# def outliers(x):
#        return np.abs(x- x.median()) > 1.5*(x.quantile(.75)-x.quantile(0.25))

# %% [raw]
# def replace(x):
#        out = x[outliers(x)]
#        return x.replace(to_replace = [out.min(),out.max()],
#                         value = [np.percentile(x,5),np.percentile(x,95)])
#
#
# data = data.apply(replace,axis=1)

# %% [raw]
# data = data[~data.apply(outliers).any(axis=1)]

# %% [raw]
# def find_outliers_tukey(x):
#     q1 = x.quantile(.25)
#     q3 = x.quantile(.75)
#     iqr = q3 - q1
#     floor = q1 - 1.5*iqr
#     ceiling = q3 + 1.5*iqr
#     outlier_indices = list(x.index[(x < floor) | (x > ceiling)])
#     outlier_values = list(x[outlier_indices])
#    # return outlier_indices, outlier_values

# %%
data.boxplot(['Age'])
# Out:
# <AxesSubplot:>

# %%
Q1=np.percentile(data['Age'],25,interpolation='midpoint')
Q3=np.percentile(data['Age'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q3)
# Out:
# 19.0
# 27.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 8.0

# %%
low_lim=Q1-1.5*IQR
upp_lim=Q3+1.5*IQR

# %%
print(low_lim)
print(upp_lim)
# Out:
# 7.0
# 39.0

# %%
outlier=[]
for x in data['Age']:
    if((x>upp_lim) or (x<low_lim)):
        outlier.append(x)

# %% [raw]
# median = data['Age'].median()
# std = data['Age'].std()
# outliers = (data['Age'] - median).abs() > std
# data[outliers] = np.nan
# data['Age'].fillna(median, inplace=True)

# %%
ind1 = data['Age']>upp_lim
data.drop(data.loc[ind1].index,inplace=True)

# %%
ind2=data['Age']<low_lim
data.drop(data.loc[ind2].index,inplace=True)

# %%
data.boxplot(['Age'])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(['Height'])
# Out:
# <AxesSubplot:>

# %%
Q1=np.percentile(data['Height'],25,interpolation='midpoint')
Q3=np.percentile(data['Height'],75,interpolation='midpoint')

# %%
IQR=Q3-Q1
IQR
# Out:
# 10.0

# %%
low_lim=Q1-1.5*IQR
upp_lim=Q3+1.5*IQR

# %%
print(low_lim)
print(upp_lim)
# Out:
# 160.0
# 200.0

# %%
outlier=[]
for x in data['Height']:
    if((x>upp_lim) or (x<low_lim)):
        outlier.append(x)
print(outlier)
# Out:
# [156.0, 205.0, 156.0, 158.0, 157.0, 157.0, 155.0, 154.0, 154.0, 159.0, 156.0, 201.0, 159.0, 159.0, 155.0, 154.0, 156.0, 158.0, 159.0, 158.0, 159.0, 159.0, 152.0, 155.0, 156.0, 155.0, 158.0, 156.0, 155.0, 152.0, 156.0, 159.0, 159.0, 158.0, 159.0, 156.0, 158.0, 157.0, 159.0, 158.0, 159.0, 201.0, 155.0, 157.0, 158.0, 156.0, 159.0, 154.0, 155.0, 155.0, 156.0, 156.0, 155.0, 159.0, 158.0, 158.0, 159.0, 158.0, 158.0, 155.0, 158.0, 156.0, 153.0, 157.0, 155.0, 154.0, 157.0, 156.0, 159.0, 157.0, 156.0, 159.0, 153.0, 152.0, 154.0, 153.0, 155.0, 158.0, 158.0, 159.0, 159.0, 155.0, 158.0, 158.0, 158.0, 158.0, 157.0, 156.0, 154.0, 159.0, 159.0, 157.0, 159.0, 157.0, 158.0, 153.0, 157.0, 158.0, 157.0, 156.0, 157.0, 158.0, 158.0, 149.0, 159.0, 159.0, 155.0, 158.0, 159.0, 158.0, 157.0, 154.0, 159.0, 159.0, 153.0, 152.0, 154.0, 203.0, 155.0, 157.0, 159.0, 158.0, 155.0, 201.0, 157.0, 156.0, 157.0, 157.0, 156.0, 158.0, 153.0, 159.0, 153.0, 158.0, 158.0, 154.0, 159.0, 156.0, 157.0, 157.0, 159.0, 159.0, 154
# ...

# %%
ind1 = data['Height']>upp_lim
data.drop(data.loc[ind1].index,inplace=True)

# %%
ind2=data['Height']<low_lim
data.drop(data.loc[ind2].index,inplace=True)

# %%
data.boxplot(['Height'])
# Out:
# <AxesSubplot:>

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn import preprocessing

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,annot=True)
# Out:
# <AxesSubplot:>

# %%
data.drop(['IntCaps','IntGoals','U21Caps','U21Goals'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (158259, 82)

# %%
data.groupby('PositionsDesc').mean()
# Out:
#                      Age      Height     Weight  AerialAbility  CommandOfArea  \
# PositionsDesc
# AM C           22.786418  176.397708  35.997980       2.123201       2.113860
# AM L           21.060938  175.773472  28.961609       2.081048       2.076782
# AM LC          23.013993  175.743545  44.790112       2.094216       2.086754
# AM R           21.201745  175.867576  29.770447       2.117775       2.105780
# AM RC          23.340496  176.065356  42.506612       2.103306       2.139669
# ...                  ...         ...        ...            ...            ...
# WB/M/AM RLC    24.500000  175.000000  65.000000       2.000000       1.916667
# WB/M/AM/S L    34.000000  177.000000  72.000000       1.000000       3.000000
# WB/M/AM/S R    20.500000  171.500000  29.000000       2.500000       1.000000
# WB/M/AM/S RL   30.000000  175.000000  65.000000       3.000000       2.000000
# WB/S R         25.000000  180.000000  70.000000       2.000000       4.000000
#
# ...

# %%
    data = data.copy()
    dummies = pd.get_dummies(data['PositionsDesc'], prefix='PositionsDesc')
    data = pd.concat([data, dummies], axis=1)
    data = data.drop('PositionsDesc', axis=1)
    data
# Out:
#                   Name   Age  Height  Weight  AerialAbility  CommandOfArea  \
# 0       Wilfred Bamnjo  36.0   178.0      79              1              1
# 1             Wang Wei  34.0   188.0      90             12              3
# 2             Liu Yang  34.0   183.0      70              1              2
# 3              Song Qi  31.0   170.0      65              1              3
# 4             Chen Lei  33.0   181.0      70              3              3
# ...                ...   ...     ...     ...            ...            ...
# 159536   Scott Palguta  33.0   188.0      87              1              1
# 159537     Jamie Dodds  34.0   183.0      75              1              1
# 159538  Desmond Tachie  32.0   178.0      75              1              1
# 159539   Joey Gjertsen  34.0   176.0      71              1              1
# 159540      Josh Wicks  32.0   192.0     102             11             11
#
# ...

# %%
data.shape
# Out:
# (158259, 364)

# %%
data.head()
# Out:
#              Name   Age  Height  Weight  AerialAbility  CommandOfArea  \
# 0  Wilfred Bamnjo  36.0   178.0      79              1              1
# 1        Wang Wei  34.0   188.0      90             12              3
# 2        Liu Yang  34.0   183.0      70              1              2
# 3         Song Qi  31.0   170.0      65              1              3
# 4        Chen Lei  33.0   181.0      70              3              3
#
#    Communication  Eccentricity  Handling  Kicking  OneOnOnes  Reflexes  \
# 0              2             2         3        3          1         4
# 1              5             1        12        6          2         1
# 2              4             2         1        1          1         3
# 3              1             3         2        2          1         2
# 4              2             3         1        1          3         3
#
#    RushingOut  TendencyToPunch  Throwing  Corners  Crossing  Dribbling  \
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# Name
# Age
# Height
# Weight
# AerialAbility
# CommandOfArea
# Communication
# Eccentricity
# Handling
# Kicking
# OneOnOnes
# Reflexes
# RushingOut
# TendencyToPunch
# Throwing
# Corners
# Crossing
# Dribbling
# Finishing
# FirstTouch
# Freekicks
# Heading
# LongShots
# Longthrows
# Marking
# Passing
# PenaltyTaking
# Tackling
# Technique
# Aggression
# Anticipation
# Bravery
# Composure
# Concentration
# Vision
# Decisions
# Determination
# Flair
# Leadership
# OffTheBall
# Positioning
# Teamwork
# Workrate
# Acceleration
# Agility
# Balance
# Jumping
# LeftFoot
# NaturalFitness
# Pace
# RightFoot
# Stamina
# Strength
# Consistency
# Dirtiness
# ImportantMatches
# InjuryProness
# Versatility
# Adaptability
# Ambition
# Loyalty
# Pressure
# Professional
# Sportsmanship
# Temperament
# Controversy
# Goalkeeper
# Sweeper
# Striker
# AttackingMidCentral
# AttackingMidLeft
# AttackingMidRight
# DefenderCentral
# DefenderLeft
# DefenderRight
# DefensiveMidfielder
# MidfielderCentral
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(data)
scaled_data=scaler.transform(data)
scaled_data
