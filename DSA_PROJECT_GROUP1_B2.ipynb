# %% [markdown]
# # Importing basic Libraries

# %%
#Basic Operations
import pandas as pd
import numpy as np

#For Visualizatins
import seaborn as sns
import matplotlib.pyplot as plt

#To ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the dataset into the environment
data=pd.read_csv('dataset_players.csv')

# %%
#Checking the first 5 columns of the dataset
data.head(5)
# Out:
#        UID            Name  NationID        Born  Age  IntCaps  IntGoals  \
# 0  1000055  Wilfred Bamnjo        11  27-03-1980   36        0       0.0
# 1  1000331        Wang Wei       110  20-02-1982   34        0       0.0
# 2  1000334        Liu Yang       110  11-04-1982   34        0       0.0
# 3  1000337         Song Qi       110  07-04-1985   31        0       0.0
# 4  1000340        Chen Lei       110  20-01-1983   33        0       0.0
#
#    U21Caps  U21Goals  Height  ...  AttackingMidRight  DefenderCentral  \
# 0      0.0         0   178.0  ...                  1                1
# 1      0.0         0   188.0  ...                  1                1
# 2      0.0         0   183.0  ...                  1                1
# 3      0.0         0   170.0  ...                  1                1
# 4      0.0         0   181.0  ...                  1                1
#
#    DefenderLeft  DefenderRight  DefensiveMidfielder  MidfielderCentral  \
# ...

# %%
data.tail()
# Out:
#            UID            Name  NationID        Born  Age  IntCaps  IntGoals  \
# 159536  981931   Scott Palguta       390  23-08-1982   33        0       0.0
# 159537  981959     Jamie Dodds       364  12-11-1981   34        0       0.0
# 159538  981962  Desmond Tachie       364  01-05-1984   32        0       0.0
# 159539  981967   Joey Gjertsen       390  13-06-1982   34        0       0.0
# 159540  981968      Josh Wicks       390  01-11-1983   32        0       0.0
#
#         U21Caps  U21Goals  Height  ...  AttackingMidRight  DefenderCentral  \
# 159536      0.0         0     NaN  ...                  1               17
# 159537      0.0         0   183.0  ...                 15                1
# 159538      0.0         0   178.0  ...                  1                1
# 159539      0.0         0   176.0  ...                 16                1
# 159540      0.0         0     NaN  ...                  1                1
#
# ...

# %% [markdown]
# # Descriptive Analysis

# %%
data.describe()
# Out:
#                 UID      NationID            Age        IntCaps  \
# count  1.595410e+05  1.595410e+05  159541.000000  159541.000000
# mean   1.368157e+08  7.621294e+04      23.578033       0.988987
# std    3.492948e+08  2.051496e+06       5.640172       6.642102
# min    5.100000e+02  5.000000e+00      14.000000       0.000000
# 25%    1.902265e+07  7.610000e+02      19.000000       0.000000
# 50%    4.104476e+07  7.760000e+02      23.000000       0.000000
# 75%    6.723302e+07  7.990000e+02      27.000000       0.000000
# max    1.394674e+09  6.200213e+07      54.000000     166.000000
#
#             IntGoals        U21Caps       U21Goals         Height  \
# count  159073.000000  159480.000000  159541.000000  159084.000000
# mean        0.108466       0.507619       0.065883     180.022102
# std         1.271062       2.535760       0.591362       7.220019
# min         0.000000       0.000000       0.000000     149.000000
# ...

# %%
data.shape
# Out:
# (159541, 89)

# %% [markdown]
# There are 159541 rows and 89 columns in the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159541 entries, 0 to 159540
# Data columns (total 89 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   UID                  159541 non-null  int64
#  1   Name                 159541 non-null  object
#  2   NationID             159541 non-null  int64
#  3   Born                 156270 non-null  object
#  4   Age                  159541 non-null  int64
#  5   IntCaps              159541 non-null  int64
#  6   IntGoals             159073 non-null  float64
#  7   U21Caps              159480 non-null  float64
#  8   U21Goals             159541 non-null  int64
#  9   Height               159084 non-null  float64
#  10  Weight               159541 non-null  int64
#  11  AerialAbility        159541 non-null  int64
#  12  CommandOfArea        159541 non-null  int64
#  13  Communication        159316 non-null  float64
#  14  Eccentricity         159541 non-null  int64
# ...

# %% [markdown]
# There are float,int,object type datatypes in the data.Also there are null values in the dataset.

# %%
data.isna().sum()[data.isna().sum()>0]
# Out:
# Born             3271
# IntGoals          468
# U21Caps            61
# Height            457
# Communication     225
# Aggression        817
# PositionsDesc     220
# dtype: int64

# %%
#Filling the null value columns

cols=['IntGoals','U21Caps','Height','Communication','Aggression']

for i in cols:
    data[i].fillna(data[i].mean(),inplace=True)

# %%
data['PositionsDesc'].fillna( method ='ffill', inplace = True)

# %%
data['Born'].fillna('not known',inplace=True)

# %%
data.isna().sum()[data.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Now there is no null values in the dataset.

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Distribution of age of players
x=data['Age']
plt.figure(figsize=(10,8))
ax=sns.countplot(x,color='#00ffff')
ax.set_xlabel(xlabel='Age of Players',fontsize=16)
ax.set_title(label='Distribution of Age of Players',fontsize=20)
plt.show()

# %% [markdown]
# from the visualization we can see that most of the players are in the age group of 16-27 years

# %%
plt.figure(figsize = (20, 8))
plt.style.use('fivethirtyeight')
ax = sns.countplot('PositionsDesc', data = data, palette = 'bone')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 16)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 16)
ax.set_title(label = 'Comparison of Positions and Players', fontsize = 20)
plt.show()

# %%
data['Height']=data['Height'].astype(int)

# %%
#count of players on the basis of heights
plt.figure(figsize = (25,15))
ax = sns.countplot(x = 'Height', data = data, palette = 'dark')
ax.set_title(label = 'Count of players on Basis of Height', fontsize = 20)
ax.set_xlabel(xlabel = 'Height of the player', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %%
#weight of players
from matplotlib import style

plt.figure(figsize = (20, 5))
plt.style.available
sns.distplot(data['Weight'], color = 'pink')
plt.title('Different Weights of the Players ', fontsize = 20)
plt.xlabel('Weights associated with the players', fontsize = 16)
plt.ylabel('count of Players', fontsize = 16)
plt.show()

# %%
plt.figure(figsize = (10, 8))
ax = sns.countplot(x = 'Positioning', data = data, palette = 'pastel')
ax.set_title(label = 'Count of players on Basis of their positioning', fontsize = 20)
ax.set_xlabel(xlabel = 'Number of positioning ', fontsize = 16)
ax.set_ylabel(ylabel = 'Count', fontsize = 16)
plt.show()

# %%
#violin plot
plt.rcParams['figure.figsize'] = (20, 7)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(data['Decisions'], data['Leadership'], hue = data['Age'], palette = 'Greys')
plt.title('Comparison of Decisions and Leadership with respect to Age', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 7)
plt.style.use('seaborn-dark-palette')

sns.boxenplot(data['Stamina'], data['Consistency'], hue = data['ImportantMatches'], palette = 'Greys')
plt.title('Comparison of stamina and consistency with respect to important matches', fontsize = 20)
plt.show()

# %%
#Finding 15 youngest players from the data set
data.sort_values('Age', ascending = True)[['Name', 'Age', 'NationID', 'PositionsDesc']].head(15).style.background_gradient('viridis')
# Out:
# <style  type="text/css" >
# #T_1ea85_row0_col1,#T_1ea85_row1_col1,#T_1ea85_row2_col1,#T_1ea85_row3_col1,#T_1ea85_row4_col1,#T_1ea85_row5_col1,#T_1ea85_row6_col1,#T_1ea85_row7_col1,#T_1ea85_row8_col1,#T_1ea85_row8_col2,#T_1ea85_row9_col1,#T_1ea85_row10_col1,#T_1ea85_row11_col1,#T_1ea85_row11_col2,#T_1ea85_row12_col1,#T_1ea85_row12_col2,#T_1ea85_row13_col1,#T_1ea85_row13_col2,#T_1ea85_row14_col1{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_1ea85_row0_col2,#T_1ea85_row2_col2,#T_1ea85_row3_col2,#T_1ea85_row5_col2,#T_1ea85_row7_col2,#T_1ea85_row10_col2,#T_1ea85_row14_col2{
#             background-color:  #f6e620;
#             color:  #000000;
#         }#T_1ea85_row1_col2,#T_1ea85_row4_col2,#T_1ea85_row6_col2,#T_1ea85_row9_col2{
#             background-color:  #fde725;
#             color:  #000000;
# ...

# %%
#Finding 15 eldest players from the dataset
data.sort_values('Age',ascending=False)[['Name', 'Age', 'NationID', 'PositionsDesc']].head(15).style.background_gradient('inferno')
# Out:
# <style  type="text/css" >
# #T_ed34d_row0_col1,#T_ed34d_row1_col1,#T_ed34d_row1_col2,#T_ed34d_row2_col1,#T_ed34d_row3_col1{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_ed34d_row0_col2{
#             background-color:  #310a5c;
#             color:  #f1f1f1;
#         }#T_ed34d_row2_col2,#T_ed34d_row13_col2{
#             background-color:  #a22b62;
#             color:  #f1f1f1;
#         }#T_ed34d_row3_col2,#T_ed34d_row11_col2,#T_ed34d_row12_col1,#T_ed34d_row13_col1,#T_ed34d_row14_col1,#T_ed34d_row14_col2{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_ed34d_row4_col1{
#             background-color:  #fca50a;
#             color:  #000000;
#         }#T_ed34d_row4_col2{
#             background-color:  #a32c61;
#             color:  #f1f1f1;
#         }#T_ed34d_row5_col1,#T_ed34d_row6_col1{
#             background-color:  #932667;
#             color:  #f1f1f1;
# ...

# %%
#Number of players in different positions
position_count = data.groupby('PositionsDesc').count()
position_count = position_count['Name']
position_count
# Out:
# PositionsDesc
# AM C            4005
# AM L            1664
# AM LC           1081
# AM R            1852
# AM RC           1220
#                 ...
# WB/M/AM RL        35
# WB/M/AM RLC       12
# WB/M/AM/S R        2
# WB/M/AM/S RL       1
# WB/S R             1
# Name: Name, Length: 285, dtype: int64
